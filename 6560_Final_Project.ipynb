# %% [markdown]
# <a href="https://colab.research.google.com/github/kmbecker19/EC_Final_Project/blob/main/6560_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" Evolutionary Deep Neural Net:

This project is an evolutionary algorithm used to build and optimize the architecture
of a deep neural network. The neural net in question is tested on the fashion MIST
data set, altough changed to the code can be made to accomidate other other 
data sets."""

# !pip install deap

# TensorFlow and tf.keras
import tensorflow as tf

from tensorflow.keras.layers import (Dense, Dropout, Flatten, Activation)
from tensorflow.keras.activations import (relu, tanh, sigmoid, softmax)

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from deap import tools, creator, base, algorithms
import random, numpy, copy, keras

EPOCHS = 2
CXPB = 0.0
MUTPB =1.0
NGEN = 50
MU = 1
LAMBDA= 4
MAX_NODES = 128
activations = [sigmoid, relu, tanh, softmax]

#Import fashion dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images.shape
train_images = train_images / 255.0
test_images = test_images / 255.0

def compileAndTrain(ind):
  ind[0].compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
  ind[0].fit(train_images, train_labels, epochs=EPOCHS)

def evaluate(ind):
  """test the neural network"""
  test_loss, test_acc = ind[0].evaluate(test_images,  test_labels, verbose=2)
  return (test_acc,)

def mutAddLayer(ind):
  if len(ind[0].layers) >= 5:
    if random.random()<0.5:
      return mutChangeActivation(ind)
    else:
      return mutChangeLayerSize(ind)
  else:
    child = copy.deepcopy(ind)
    nodes = random.randint(0, MAX_NODES+1)
    child_net = child[0]
    child_net.pop()
    child_net.add(tf.keras.layers.Dense(nodes, 
                  activation = activations[random.randint(0,3)]))
    child_net.add(tf.keras.layers.Dense(10))
    child[0] = child_net#Just in case
    compileAndTrain(child)
    # print ("mutated:", child[0].summary())
    return (child,)

def mutChangeActivation(ind):
    child = copy.deepcopy(ind)
    ind_net = ind[0]
    if len(ind_net.layers) <= 2:
      return mutAddLayer(ind)
    maxdepth = len(ind_net.layers) - 2
    depth = random.randint(1, maxdepth)
    activation = activations[random.randint(0,3)]
    model = tf.keras.Sequential([Flatten(input_shape=(28,28))])
    for i in range(1,len(ind_net.layers)-1):
      if i == depth:
        model.add(Dense(ind_net.layers[i].units, activation))
      else:
        model.add(Dense(ind_net.layers[i].units, ind_net.layers[i].activation))
    model.add(Dense(10))
    child+=[model]
    child.pop(0)
    compileAndTrain(child)
    # print ("mutated:", child[0].summary())
    return (child,)


def mutRemoveLayer(ind):
  child = copy.deepcopy(ind)
  ind_net = ind[0]
  if len(ind_net.layers) > 2:
    maxdepth = len(ind_net.layers) - 2
    depth = random.randint(1, maxdepth) #depth of removal
    #create child
    model = tf.keras.Sequential([Flatten(input_shape=(28,28))])
    for i in range(1,len(ind_net.layers)-1):
      if not i == depth:
        model.add(Dense(ind_net.layers[i].units, ind_net.layers[i].activation))
    model.add(Dense(10))
    child+=[model]
    child.pop(0)
    compileAndTrain(child)
    # print ("mutated:", child[0].summary())
    return (child,)   
  else:
    # if child is too small, we add a dense layer
    return mutAddLayer(ind)
      

def mutAddDropout(ind):
    child = copy.deepcopy(ind)
    child_net = child[0]
    if len(child_net.layers) <= 2:
      return mutAddLayer(ind)
    drop = random.uniform(0, 0.5)
    child_net.pop()
    child_net.add(Dropout(drop))
    child_net.add(Dense(10))
    child[0] = child_net#Just in case



    compileAndTrain(child)
    return (child,)

def mutChangeLayerSize(ind):
  child = copy.deepcopy(ind)
  ind_net = ind[0]
  # if child is too small, we add a dense layer
  if len(ind_net.layers) <= 2:
    return mutAddLayer(ind)
  else:
    maxdepth = len(ind_net.layers) - 2
    depth = random.randint(1, maxdepth)
    nodes = random.randint(0, MAX_NODES)
    model = tf.keras.Sequential([Flatten(input_shape=(28,28))])
    for i in range(1,len(ind_net.layers)-1):
      if i == depth:
        model.add(Dense(nodes, ind_net.layers[i].activation))
      else:
        model.add(Dense(ind_net.layers[i].units, ind_net.layers[i].activation))
    model.add(Dense(10))
    child+=[model]
    child.pop(0)
    compileAndTrain(child)
    return (child,)

def cloneAndMutate(population, toolbox, lambda_, cxpb, mutpb):
    assert (cxpb + mutpb) <= 1.0, (
        "The sum of the crossover and mutation probabilities must be smaller "
        "or equal to 1.0.")

    offspring = []
    for i in range(lambda_):
        op_choice = random.random()
        if op_choice < mutpb:  # Apply mutation
            ind = toolbox.clone(random.choice(population))
            if i % 3 == 0:
              ind, = toolbox.mutate1(ind)
            if i % 3 == 1:
              ind, = toolbox.mutate2(ind)
            elif i % 3 == 2:
              ind, = toolbox.mutate3(ind)
            elif i % 3 == 3:
              ind, = toolbox.mutate4(ind)
            del ind.fitness.values
            offspring.append(ind)
        else:                           # Apply reproduction
            offspring.append(random.choice(population))

    return offspring


def muPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen,
                   stats=None, halloffame=None, verbose=__debug__):
    logbook = tools.Logbook()
    logbook.header = ['gen', 'nevals'] + (stats.fields if stats else [])

    # Evaluate the individuals with an invalid fitness
    invalid_ind = [ind for ind in population if not ind.fitness.valid]
    fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit

    if halloffame is not None:
        halloffame.update(population)

    record = stats.compile(population) if stats is not None else {}
    logbook.record(gen=0, nevals=len(invalid_ind), **record)
    if verbose:
        print(logbook.stream)

    # Begin the generational process
    for gen in range(1, ngen + 1):
        # Vary the population
        offspring = cloneAndMutate(population, toolbox, lambda_, cxpb, mutpb)

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        # Update the hall of fame with the generated individuals
        if halloffame is not None:
            halloffame.update(offspring)

        # Select the next generation population
        population[:] = toolbox.select(population + offspring, mu)

        # Update the statistics with the new population
        record = stats.compile(population) if stats is not None else {}
        logbook.record(gen=gen, nevals=len(invalid_ind), **record)
        if verbose:
            print(logbook.stream)
            ind = population[0]
    return population, logbook
  

def createEA():
  def initIndividual(icls):
    model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
     #placeholder layer
    tf.keras.layers.Dense(10)
    ])
    #compile and trian network
    model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=EPOCHS)
    return icls([model])

  creator.create("FitnessMax", base.Fitness, weights=(1.0,))
  creator.create("Individual", list, fitness=creator.FitnessMax)
  toolbox = base.Toolbox()

  toolbox.register("individual", initIndividual, creator.Individual)
  toolbox.register("population", tools.initRepeat, list, toolbox.individual)
  pop = toolbox.population(n=MU)
  hof = tools.HallOfFame(MU)

  toolbox.register("mutate1", mutAddLayer)
  toolbox.register("mutate2", mutChangeActivation)
  toolbox.register("mutate3", mutChangeLayerSize)
  toolbox.register("mutate4", mutRemoveLayer)
  toolbox.register("evaluate", evaluate)
  toolbox.register("select", tools.selTournament, tournsize=4)


  #Registering descriptive statistics
  stats = tools.Statistics(lambda ind: ind.fitness.values)
  stats.register("min", numpy.min)
  stats.register("avg", numpy.mean)
  stats.register("max", numpy.max)
  stats.register("std", numpy.std)


  muPlusLambda(pop, toolbox, mu=MU, lambda_=LAMBDA, cxpb=CXPB, mutpb=MUTPB, ngen=NGEN, stats=stats, halloffame=hof, verbose=True)
  best_ind = hof[0]
  print (best_ind[0].summary())
  best_ind[0].fit(train_images, train_labels, epochs=10)
  print (evaluate(best_ind))

createEA()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deap in /usr/local/lib/python3.8/dist-packages (1.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from deap) (1.21.6)
# Epoch 1/2
# /usr/local/lib/python3.8/dist-packages/deap/creator.py:138: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.8/dist-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6028 - accuracy: 0.7970
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4624 - accuracy: 0.8414
# 313/313 - 1s - loss: 0.4817 - accuracy: 0.8325 - 515ms/epoch - 2ms/step
# gen	nevals	min   	avg   	max   	std
# 0  	1     	0.8325	0.8325	0.8325	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5151 - accuracy: 0.8213
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3858 - accuracy: 0.8619
# Epoch 1/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5447 - accuracy: 0.8137
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4155 - accuracy: 0.8533
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4752 - accuracy: 0.8316
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3705 - accuracy: 0.8661
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5137 - accuracy: 0.8214
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3960 - accuracy: 0.8593
# 313/313 - 1s - loss: 0.3942 - accuracy: 0.8571 - 568ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4331 - accuracy: 0.8455 - 522ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3863 - accuracy: 0.8630 - 609ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4423 - accuracy: 0.8424 - 516ms/epoch - 2ms/step
# 1  	4     	0.863 	0.863 	0.863 	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8623
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3271 - accuracy: 0.8798
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5541 - accuracy: 0.8107
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3936 - accuracy: 0.8590
# Epoch 1/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4987 - accuracy: 0.8232
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3786 - accuracy: 0.8633
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4266 - accuracy: 0.8504
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3388 - accuracy: 0.8760
# 313/313 - 1s - loss: 0.3776 - accuracy: 0.8669 - 1s/epoch - 4ms/step
# 313/313 - 1s - loss: 0.3999 - accuracy: 0.8566 - 610ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3951 - accuracy: 0.8595 - 566ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3770 - accuracy: 0.8638 - 615ms/epoch - 2ms/step
# 2  	4     	0.8638	0.8638	0.8638	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3883 - accuracy: 0.8619
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3145 - accuracy: 0.8848
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4051 - accuracy: 0.5521
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9207 - accuracy: 0.6409
# Epoch 1/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5213 - accuracy: 0.8154
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3758 - accuracy: 0.8639
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3847 - accuracy: 0.8632
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3136 - accuracy: 0.8850
# 313/313 - 1s - loss: 0.3702 - accuracy: 0.8656 - 604ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.8356 - accuracy: 0.6850 - 595ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3992 - accuracy: 0.8529 - 549ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3638 - accuracy: 0.8680 - 619ms/epoch - 2ms/step
# 3  	4     	0.868 	0.868 	0.868 	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5350 - accuracy: 0.8074
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3835 - accuracy: 0.8596
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4887 - accuracy: 0.4726
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.0739 - accuracy: 0.5261
# Epoch 1/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7040 - accuracy: 0.7288
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5075 - accuracy: 0.8210
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.3826 - accuracy: 0.6227
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8313 - accuracy: 0.6608
# 313/313 - 1s - loss: 0.3978 - accuracy: 0.8571 - 591ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.9947 - accuracy: 0.5892 - 601ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5080 - accuracy: 0.8217 - 518ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.7603 - accuracy: 0.6627 - 620ms/epoch - 2ms/step
# 4  	4     	0.8217	0.8217	0.8217	0
# Epoch 1/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6525 - accuracy: 0.7671
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4915 - accuracy: 0.8253
# Epoch 1/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.8229 - accuracy: 0.6992
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5550 - accuracy: 0.8000
# Epoch 1/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6602 - accuracy: 0.7562
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4918 - accuracy: 0.8234
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5000 - accuracy: 0.8199
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3708 - accuracy: 0.8653
# 313/313 - 1s - loss: 0.5249 - accuracy: 0.8128 - 509ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5805 - accuracy: 0.7972 - 504ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5088 - accuracy: 0.8168 - 519ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3798 - accuracy: 0.8648 - 601ms/epoch - 2ms/step
# 5  	4     	0.8648	0.8648	0.8648	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7004 - accuracy: 0.7471
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4428 - accuracy: 0.8442
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4912 - accuracy: 0.8213
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3663 - accuracy: 0.8652
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4773 - accuracy: 0.8256
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3658 - accuracy: 0.8643
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5198 - accuracy: 0.8112
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3696 - accuracy: 0.8649
# 313/313 - 1s - loss: 0.4529 - accuracy: 0.8408 - 597ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4121 - accuracy: 0.8455 - 604ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3751 - accuracy: 0.8637 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3971 - accuracy: 0.8561 - 600ms/epoch - 2ms/step
# 6  	4     	0.8637	0.8637	0.8637	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4846 - accuracy: 0.8230
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3648 - accuracy: 0.8657
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4827 - accuracy: 0.8252
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3641 - accuracy: 0.8650
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4780 - accuracy: 0.8249
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3660 - accuracy: 0.8659
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4875 - accuracy: 0.8236
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3697 - accuracy: 0.8641
# 313/313 - 1s - loss: 0.3889 - accuracy: 0.8571 - 599ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3756 - accuracy: 0.8618 - 599ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3887 - accuracy: 0.8605 - 612ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3926 - accuracy: 0.8547 - 598ms/epoch - 2ms/step
# 7  	4     	0.8637	0.8637	0.8637	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4819 - accuracy: 0.8257
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3666 - accuracy: 0.8639
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4805 - accuracy: 0.8256
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3671 - accuracy: 0.8650
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4856 - accuracy: 0.8247
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3682 - accuracy: 0.8633
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5589 - accuracy: 0.7937
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3847 - accuracy: 0.8604
# 313/313 - 1s - loss: 0.4007 - accuracy: 0.8536 - 609ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3836 - accuracy: 0.8584 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3800 - accuracy: 0.8617 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4255 - accuracy: 0.8459 - 591ms/epoch - 2ms/step
# 8  	4     	0.8637	0.8637	0.8637	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5139 - accuracy: 0.8205
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3665 - accuracy: 0.8660
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4827 - accuracy: 0.8224
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3607 - accuracy: 0.8655
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4791 - accuracy: 0.8260
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3647 - accuracy: 0.8647
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4802 - accuracy: 0.8248
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3658 - accuracy: 0.8654
# 313/313 - 1s - loss: 0.3914 - accuracy: 0.8595 - 611ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3914 - accuracy: 0.8528 - 614ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4017 - accuracy: 0.8515 - 597ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3909 - accuracy: 0.8599 - 590ms/epoch - 2ms/step
# 9  	4     	0.8595	0.8595	0.8595	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5161 - accuracy: 0.8172
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3694 - accuracy: 0.8645
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5145 - accuracy: 0.8160
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3736 - accuracy: 0.8636
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3028 - accuracy: 0.0982
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3027 - accuracy: 0.1007
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5280 - accuracy: 0.8140
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3719 - accuracy: 0.8636
# 313/313 - 1s - loss: 0.3795 - accuracy: 0.8602 - 610ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4000 - accuracy: 0.8567 - 616ms/epoch - 2ms/step
# 313/313 - 1s - loss: 2.3027 - accuracy: 0.1000 - 596ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3952 - accuracy: 0.8564 - 593ms/epoch - 2ms/step
# 10 	4     	0.8595	0.8595	0.8595	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5111 - accuracy: 0.8170
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3727 - accuracy: 0.8624
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4795 - accuracy: 0.8254
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3667 - accuracy: 0.8648
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5149 - accuracy: 0.8162
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3689 - accuracy: 0.8648
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6248 - accuracy: 0.7913
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3799 - accuracy: 0.8633
# 313/313 - 1s - loss: 0.3995 - accuracy: 0.8499 - 609ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3881 - accuracy: 0.8561 - 600ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3895 - accuracy: 0.8591 - 601ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4060 - accuracy: 0.8512 - 607ms/epoch - 2ms/step
# 11 	4     	0.8595	0.8595	0.8595	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5343 - accuracy: 0.8083
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3690 - accuracy: 0.8652
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5178 - accuracy: 0.8197
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3726 - accuracy: 0.8631
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5141 - accuracy: 0.8180
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3712 - accuracy: 0.8634
# Epoch 1/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5959 - accuracy: 0.7879
# Epoch 2/2
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3941 - accuracy: 0.8567
# 313/313 - 1s - loss: 0.3865 - accuracy: 0.8567 - 599ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3929 - accuracy: 0.8533 - 611ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3828 - accuracy: 0.8620 - 620ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4395 - accuracy: 0.8388 - 520ms/epoch - 2ms/step
# 12 	4     	0.862 	0.862 	0.862 	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5199 - accuracy: 0.8190
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3729 - accuracy: 0.8651
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5894 - accuracy: 0.7936
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3906 - accuracy: 0.8560
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5223 - accuracy: 0.8161
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3707 - accuracy: 0.8658
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5227 - accuracy: 0.8160
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3731 - accuracy: 0.8643
# 313/313 - 1s - loss: 0.4025 - accuracy: 0.8518 - 611ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4112 - accuracy: 0.8527 - 605ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3802 - accuracy: 0.8645 - 613ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4082 - accuracy: 0.8505 - 612ms/epoch - 2ms/step
# 13 	4     	0.8527	0.8527	0.8527	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5816 - accuracy: 0.7924
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3920 - accuracy: 0.8559
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5996 - accuracy: 0.7878
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3914 - accuracy: 0.8570
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6459 - accuracy: 0.7728
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4041 - accuracy: 0.8534
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6016 - accuracy: 0.7854
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3946 - accuracy: 0.8557
# 313/313 - 1s - loss: 0.4005 - accuracy: 0.8568 - 613ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3942 - accuracy: 0.8582 - 616ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4282 - accuracy: 0.8495 - 562ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4209 - accuracy: 0.8472 - 591ms/epoch - 2ms/step
# 14 	4     	0.8568	0.8568	0.8568	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.8686 - accuracy: 0.2201
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5081 - accuracy: 0.3557
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5752 - accuracy: 0.7952
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3845 - accuracy: 0.8611
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5973 - accuracy: 0.7902
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3913 - accuracy: 0.8579
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.7361 - accuracy: 0.7399
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3992 - accuracy: 0.8572
# 313/313 - 1s - loss: 1.3865 - accuracy: 0.3989 - 629ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3965 - accuracy: 0.8538 - 628ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3952 - accuracy: 0.8566 - 600ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4035 - accuracy: 0.8532 - 615ms/epoch - 2ms/step
# 15 	4     	0.8568	0.8568	0.8568	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5723 - accuracy: 0.7983
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3922 - accuracy: 0.8585
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6086 - accuracy: 0.7824
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3903 - accuracy: 0.8585
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6702 - accuracy: 0.7695
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4082 - accuracy: 0.8540
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5935 - accuracy: 0.7873
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3949 - accuracy: 0.8585
# 313/313 - 1s - loss: 0.4089 - accuracy: 0.8547 - 644ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3966 - accuracy: 0.8538 - 637ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4345 - accuracy: 0.8416 - 612ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3965 - accuracy: 0.8556 - 618ms/epoch - 2ms/step
# 16 	4     	0.8568	0.8568	0.8568	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5962 - accuracy: 0.7904
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3939 - accuracy: 0.8567
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5817 - accuracy: 0.7952
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3900 - accuracy: 0.8591
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5870 - accuracy: 0.7926
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3909 - accuracy: 0.8586
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6422 - accuracy: 0.7743
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4054 - accuracy: 0.8542
# 313/313 - 1s - loss: 0.3940 - accuracy: 0.8560 - 596ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4004 - accuracy: 0.8559 - 611ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4098 - accuracy: 0.8490 - 614ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4243 - accuracy: 0.8454 - 543ms/epoch - 2ms/step
# 17 	4     	0.8568	0.8568	0.8568	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.0961 - accuracy: 0.5899
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4350 - accuracy: 0.8474
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5756 - accuracy: 0.7992
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3900 - accuracy: 0.8578
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6692 - accuracy: 0.7707
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4054 - accuracy: 0.8536
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5148 - accuracy: 0.8148
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3784 - accuracy: 0.8604
# 313/313 - 1s - loss: 0.4355 - accuracy: 0.8439 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4064 - accuracy: 0.8541 - 614ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4150 - accuracy: 0.8504 - 615ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3923 - accuracy: 0.8609 - 598ms/epoch - 2ms/step
# 18 	4     	0.8609	0.8609	0.8609	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5079 - accuracy: 0.8179
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3797 - accuracy: 0.8609
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4778 - accuracy: 0.8263
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3638 - accuracy: 0.8657
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5273 - accuracy: 0.8126
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3766 - accuracy: 0.8616
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5385 - accuracy: 0.8082
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3800 - accuracy: 0.8614
# 313/313 - 1s - loss: 0.4033 - accuracy: 0.8538 - 652ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3699 - accuracy: 0.8655 - 601ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3924 - accuracy: 0.8598 - 618ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3900 - accuracy: 0.8584 - 615ms/epoch - 2ms/step
# 19 	4     	0.8655	0.8655	0.8655	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4811 - accuracy: 0.8265
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3617 - accuracy: 0.8644
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.7393 - accuracy: 0.7359
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4377 - accuracy: 0.8437
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4866 - accuracy: 0.8246
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3659 - accuracy: 0.8643
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4875 - accuracy: 0.8230
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3651 - accuracy: 0.8668
# 313/313 - 1s - loss: 0.3679 - accuracy: 0.8680 - 610ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4118 - accuracy: 0.8562 - 614ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3798 - accuracy: 0.8635 - 626ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3842 - accuracy: 0.8560 - 602ms/epoch - 2ms/step
# 20 	4     	0.868 	0.868 	0.868 	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4789 - accuracy: 0.8252
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3600 - accuracy: 0.8669
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5345 - accuracy: 0.8162
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3652 - accuracy: 0.8676
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5077 - accuracy: 0.8204
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3729 - accuracy: 0.8633
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4910 - accuracy: 0.8223
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3682 - accuracy: 0.8642
# 313/313 - 1s - loss: 0.3794 - accuracy: 0.8637 - 610ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3833 - accuracy: 0.8628 - 615ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3967 - accuracy: 0.8536 - 612ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3957 - accuracy: 0.8601 - 589ms/epoch - 2ms/step
# 21 	4     	0.868 	0.868 	0.868 	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4760 - accuracy: 0.8290
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3625 - accuracy: 0.8674
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6417 - accuracy: 0.7551
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4247 - accuracy: 0.8494
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4898 - accuracy: 0.8218
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3655 - accuracy: 0.8639
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5330 - accuracy: 0.8176
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3651 - accuracy: 0.8684
# 313/313 - 1s - loss: 0.3992 - accuracy: 0.8513 - 630ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4468 - accuracy: 0.8443 - 619ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3751 - accuracy: 0.8667 - 586ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3737 - accuracy: 0.8679 - 613ms/epoch - 2ms/step
# 22 	4     	0.8667	0.8667	0.8667	0
# Epoch 1/2
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4836 - accuracy: 0.8248
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3676 - accuracy: 0.8662
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4794 - accuracy: 0.8241
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3645 - accuracy: 0.8667
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5034 - accuracy: 0.8189
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3634 - accuracy: 0.8668
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4867 - accuracy: 0.8228
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3675 - accuracy: 0.8648
# 313/313 - 1s - loss: 0.3697 - accuracy: 0.8673 - 598ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3820 - accuracy: 0.8619 - 595ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3731 - accuracy: 0.8647 - 590ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3793 - accuracy: 0.8644 - 606ms/epoch - 2ms/step
# 23 	4     	0.8667	0.8667	0.8667	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5492 - accuracy: 0.8164
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3679 - accuracy: 0.8669
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5337 - accuracy: 0.8077
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3732 - accuracy: 0.8628
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4751 - accuracy: 0.8286
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3605 - accuracy: 0.8664
# Epoch 1/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5141 - accuracy: 0.8131
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3816 - accuracy: 0.8604
# 313/313 - 1s - loss: 0.3990 - accuracy: 0.8498 - 619ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3872 - accuracy: 0.8560 - 619ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3889 - accuracy: 0.8615 - 616ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3862 - accuracy: 0.8608 - 526ms/epoch - 2ms/step
# 24 	4     	0.8615	0.8615	0.8615	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5004 - accuracy: 0.8213
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3702 - accuracy: 0.8634
# Epoch 1/2
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5004 - accuracy: 0.8201
# Epoch 2/2
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3722 - accuracy: 0.8645
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4792 - accuracy: 0.8263
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3636 - accuracy: 0.8657
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5194 - accuracy: 0.8204
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3613 - accuracy: 0.8679
# 313/313 - 1s - loss: 0.4028 - accuracy: 0.8575 - 608ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4431 - accuracy: 0.8353 - 593ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3981 - accuracy: 0.8555 - 619ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3751 - accuracy: 0.8671 - 610ms/epoch - 2ms/step
# 25 	4     	0.8615	0.8615	0.8615	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4942 - accuracy: 0.8209
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3657 - accuracy: 0.8655
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4799 - accuracy: 0.8236
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3576 - accuracy: 0.8669
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4990 - accuracy: 0.8221
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3683 - accuracy: 0.8652
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4788 - accuracy: 0.8261
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3640 - accuracy: 0.8643
# 313/313 - 1s - loss: 0.3946 - accuracy: 0.8544 - 602ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3892 - accuracy: 0.8596 - 602ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3736 - accuracy: 0.8679 - 599ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3814 - accuracy: 0.8616 - 589ms/epoch - 2ms/step
# 26 	4     	0.8679	0.8679	0.8679	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4772 - accuracy: 0.8263
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3645 - accuracy: 0.8653
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5075 - accuracy: 0.8187
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3754 - accuracy: 0.8637
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5041 - accuracy: 0.8210
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3721 - accuracy: 0.8627
# Epoch 1/2
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6580 - accuracy: 0.7580
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4328 - accuracy: 0.8449
# 313/313 - 1s - loss: 0.3745 - accuracy: 0.8649 - 599ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3765 - accuracy: 0.8628 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3876 - accuracy: 0.8568 - 597ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4343 - accuracy: 0.8517 - 583ms/epoch - 2ms/step
# 27 	4     	0.8649	0.8649	0.8649	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4811 - accuracy: 0.8255
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3627 - accuracy: 0.8665
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4834 - accuracy: 0.8240
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3645 - accuracy: 0.8663
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4796 - accuracy: 0.8270
# Epoch 2/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3642 - accuracy: 0.8662
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4799 - accuracy: 0.8243
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3640 - accuracy: 0.8658
# 313/313 - 1s - loss: 0.3877 - accuracy: 0.8539 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3960 - accuracy: 0.8574 - 625ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3697 - accuracy: 0.8618 - 624ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3782 - accuracy: 0.8630 - 596ms/epoch - 2ms/step
# 28 	4     	0.863 	0.863 	0.863 	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.3894 - accuracy: 0.6260
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8295 - accuracy: 0.6676
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5208 - accuracy: 0.8148
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3703 - accuracy: 0.8644
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4785 - accuracy: 0.8267
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3648 - accuracy: 0.8651
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4881 - accuracy: 0.8219
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3632 - accuracy: 0.8662
# 313/313 - 1s - loss: 0.7560 - accuracy: 0.6710 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3989 - accuracy: 0.8573 - 595ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3776 - accuracy: 0.8613 - 615ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3737 - accuracy: 0.8665 - 568ms/epoch - 2ms/step
# 29 	4     	0.8665	0.8665	0.8665	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5058 - accuracy: 0.8192
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3719 - accuracy: 0.8616
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5331 - accuracy: 0.8127
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3778 - accuracy: 0.8599
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4893 - accuracy: 0.8233
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3693 - accuracy: 0.8633
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4818 - accuracy: 0.8256
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3652 - accuracy: 0.8651
# 313/313 - 1s - loss: 0.4094 - accuracy: 0.8561 - 562ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3868 - accuracy: 0.8592 - 567ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3832 - accuracy: 0.8592 - 563ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4153 - accuracy: 0.8513 - 564ms/epoch - 2ms/step
# 30 	4     	0.8592	0.8592	0.8592	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5488 - accuracy: 0.8026
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3828 - accuracy: 0.8603
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9778 - accuracy: 0.6363
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6115 - accuracy: 0.7431
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5464 - accuracy: 0.8069
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3800 - accuracy: 0.8607
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5443 - accuracy: 0.8051
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3838 - accuracy: 0.8594
# 313/313 - 1s - loss: 0.3885 - accuracy: 0.8600 - 560ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.6155 - accuracy: 0.7530 - 573ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3949 - accuracy: 0.8582 - 556ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3894 - accuracy: 0.8588 - 559ms/epoch - 2ms/step
# 31 	4     	0.86  	0.86  	0.86  	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5630 - accuracy: 0.8015
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3864 - accuracy: 0.8597
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5635 - accuracy: 0.8004
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3830 - accuracy: 0.8601
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5523 - accuracy: 0.8038
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3854 - accuracy: 0.8601
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5331 - accuracy: 0.8110
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3775 - accuracy: 0.8620
# 313/313 - 1s - loss: 0.4269 - accuracy: 0.8472 - 569ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3988 - accuracy: 0.8529 - 570ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4275 - accuracy: 0.8455 - 565ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4049 - accuracy: 0.8546 - 557ms/epoch - 2ms/step
# 32 	4     	0.86  	0.86  	0.86  	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5285 - accuracy: 0.8101
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3766 - accuracy: 0.8617
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5485 - accuracy: 0.8077
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3796 - accuracy: 0.8607
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5542 - accuracy: 0.8067
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3806 - accuracy: 0.8619
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.2043 - accuracy: 0.5336
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7519 - accuracy: 0.7133
# 313/313 - 1s - loss: 0.4040 - accuracy: 0.8525 - 551ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3971 - accuracy: 0.8575 - 550ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3950 - accuracy: 0.8561 - 559ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.6708 - accuracy: 0.7595 - 548ms/epoch - 2ms/step
# 33 	4     	0.8575	0.8575	0.8575	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5230 - accuracy: 0.8138
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3691 - accuracy: 0.8644
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6685 - accuracy: 0.7677
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4058 - accuracy: 0.8521
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5263 - accuracy: 0.8152
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3697 - accuracy: 0.8646
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5307 - accuracy: 0.8128
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3757 - accuracy: 0.8632
# 313/313 - 1s - loss: 0.3799 - accuracy: 0.8602 - 623ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4097 - accuracy: 0.8521 - 566ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3895 - accuracy: 0.8604 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3984 - accuracy: 0.8537 - 592ms/epoch - 2ms/step
# 34 	4     	0.8604	0.8604	0.8604	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5276 - accuracy: 0.8120
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3762 - accuracy: 0.8616
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6065 - accuracy: 0.7853
# Epoch 2/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3934 - accuracy: 0.8579
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5503 - accuracy: 0.8072
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3770 - accuracy: 0.8628
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.4226 - accuracy: 0.5517
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.9289 - accuracy: 0.5744
# 313/313 - 1s - loss: 0.3864 - accuracy: 0.8577 - 592ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4046 - accuracy: 0.8556 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3916 - accuracy: 0.8576 - 621ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.8749 - accuracy: 0.5793 - 611ms/epoch - 2ms/step
# 35 	4     	0.8604	0.8604	0.8604	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5222 - accuracy: 0.8131
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3654 - accuracy: 0.8660
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.0027 - accuracy: 0.6391
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6465 - accuracy: 0.7339
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5401 - accuracy: 0.8099
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3780 - accuracy: 0.8637
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5160 - accuracy: 0.8158
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3715 - accuracy: 0.8634
# 313/313 - 1s - loss: 0.3673 - accuracy: 0.8687 - 643ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.6388 - accuracy: 0.7498 - 630ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3973 - accuracy: 0.8545 - 594ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3917 - accuracy: 0.8563 - 609ms/epoch - 2ms/step
# 36 	4     	0.8604	0.8604	0.8604	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5165 - accuracy: 0.8177
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3698 - accuracy: 0.8637
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5269 - accuracy: 0.8114
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3694 - accuracy: 0.8642
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5178 - accuracy: 0.8154
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3729 - accuracy: 0.8634
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6100 - accuracy: 0.7829
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4243 - accuracy: 0.8468
# 313/313 - 1s - loss: 0.3984 - accuracy: 0.8584 - 597ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3748 - accuracy: 0.8615 - 583ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3798 - accuracy: 0.8619 - 607ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4235 - accuracy: 0.8478 - 521ms/epoch - 2ms/step
# 37 	4     	0.8619	0.8619	0.8619	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5151 - accuracy: 0.8176
# Epoch 2/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3720 - accuracy: 0.8643
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.9907 - accuracy: 0.6105
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6371 - accuracy: 0.7368
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.7469 - accuracy: 0.7338
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4338 - accuracy: 0.8502
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8890 - accuracy: 0.6806
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5573 - accuracy: 0.7702
# 313/313 - 1s - loss: 0.4144 - accuracy: 0.8524 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.6215 - accuracy: 0.7456 - 612ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4288 - accuracy: 0.8523 - 607ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5450 - accuracy: 0.7930 - 599ms/epoch - 2ms/step
# 38 	4     	0.8619	0.8619	0.8619	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5067 - accuracy: 0.8189
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3704 - accuracy: 0.8642
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8387 - accuracy: 0.6594
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4483 - accuracy: 0.8325
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5439 - accuracy: 0.8038
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3862 - accuracy: 0.8590
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8706 - accuracy: 0.6848
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5368 - accuracy: 0.7818
# 313/313 - 1s - loss: 0.3797 - accuracy: 0.8624 - 600ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4278 - accuracy: 0.8484 - 606ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4186 - accuracy: 0.8453 - 562ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5392 - accuracy: 0.7971 - 622ms/epoch - 2ms/step
# 39 	4     	0.8624	0.8624	0.8624	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4752 - accuracy: 0.8262
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3604 - accuracy: 0.8670
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5062 - accuracy: 0.8192
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3727 - accuracy: 0.8631
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5095 - accuracy: 0.8163
# Epoch 2/2
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3717 - accuracy: 0.8624
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6644 - accuracy: 0.7571
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4589 - accuracy: 0.8349
# 313/313 - 1s - loss: 0.4024 - accuracy: 0.8501 - 643ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3878 - accuracy: 0.8642 - 628ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3902 - accuracy: 0.8584 - 602ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4592 - accuracy: 0.8332 - 522ms/epoch - 2ms/step
# 40 	4     	0.8584	0.8584	0.8584	0
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5786 - accuracy: 0.7925
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4119 - accuracy: 0.8480
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.5026 - accuracy: 0.4554
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.0650 - accuracy: 0.5020
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5108 - accuracy: 0.8166
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3680 - accuracy: 0.8639
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8271 - accuracy: 0.6890
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5688 - accuracy: 0.7630
# 313/313 - 1s - loss: 0.4271 - accuracy: 0.8436 - 561ms/epoch - 2ms/step
# 313/313 - 1s - loss: 1.0170 - accuracy: 0.5284 - 624ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4051 - accuracy: 0.8495 - 616ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.5828 - accuracy: 0.7794 - 604ms/epoch - 2ms/step
# 41 	4     	0.8584	0.8584	0.8584	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5107 - accuracy: 0.8166
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3694 - accuracy: 0.8641
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5126 - accuracy: 0.8162
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3743 - accuracy: 0.8621
# Epoch 1/2
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5097 - accuracy: 0.8169
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3740 - accuracy: 0.8622
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6135 - accuracy: 0.7849
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3819 - accuracy: 0.8626
# 313/313 - 1s - loss: 0.3946 - accuracy: 0.8574 - 628ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3941 - accuracy: 0.8550 - 622ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3862 - accuracy: 0.8583 - 608ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4037 - accuracy: 0.8578 - 603ms/epoch - 2ms/step
# 42 	4     	0.8584	0.8584	0.8584	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5063 - accuracy: 0.8172
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3689 - accuracy: 0.8644
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4698 - accuracy: 0.8288
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3604 - accuracy: 0.8658
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5037 - accuracy: 0.8181
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3711 - accuracy: 0.8637
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.5990 - accuracy: 0.3750
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.2264 - accuracy: 0.4127
# 313/313 - 1s - loss: 0.3951 - accuracy: 0.8560 - 614ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3827 - accuracy: 0.8615 - 621ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3833 - accuracy: 0.8614 - 605ms/epoch - 2ms/step
# 313/313 - 1s - loss: 1.1789 - accuracy: 0.4254 - 631ms/epoch - 2ms/step
# 43 	4     	0.8615	0.8615	0.8615	0
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5086 - accuracy: 0.8238
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3596 - accuracy: 0.8686
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6186 - accuracy: 0.7624
# Epoch 2/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4226 - accuracy: 0.8502
# Epoch 1/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4959 - accuracy: 0.8202
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3811 - accuracy: 0.8596
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4767 - accuracy: 0.8252
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3597 - accuracy: 0.8664
# 313/313 - 1s - loss: 0.3908 - accuracy: 0.8602 - 609ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4641 - accuracy: 0.8372 - 598ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4033 - accuracy: 0.8552 - 529ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3790 - accuracy: 0.8641 - 596ms/epoch - 2ms/step
# 44 	4     	0.8641	0.8641	0.8641	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4655 - accuracy: 0.8297
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3570 - accuracy: 0.8676
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4829 - accuracy: 0.8245
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3618 - accuracy: 0.8659
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5021 - accuracy: 0.8163
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3788 - accuracy: 0.8601
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4702 - accuracy: 0.8290
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3567 - accuracy: 0.8677
# 313/313 - 1s - loss: 0.3814 - accuracy: 0.8529 - 603ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3767 - accuracy: 0.8649 - 592ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.4098 - accuracy: 0.8500 - 536ms/epoch - 2ms/step
# 313/313 - 1s - loss: 0.3694 - accuracy: 0.8650 - 603ms/epoch - 2ms/step
# 45 	4     	0.8641	0.8641	0.8641	0
# Epoch 1/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5188 - accuracy: 0.8198
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3625 - accuracy: 0.8664
# Epoch 1/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8558 - accuracy: 0.6507
# Epoch 2/2
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4766 - accuracy: 0.8252
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5607 - accuracy: 0.8071
# Epoch 2/2
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3921 - accuracy: 0.8589

# %% [markdown]
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_3 (Dense)             (None, 54)                42390
#
#  dense_15 (Dense)            (None, 91)                5005
#
#  dense_27 (Dense)            (None, 84)                7728
#
#  dense_28 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 55,973
# Trainable params: 55,973
# Non-trainable params: 0
# _________________________________________________________________
#
#
# 313/313 - 1s - loss: 0.3290 - accuracy: 0.8880 - 646ms/epoch - 2ms/step
#
#
# (0.8880000114440918,)
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_193 (Flatten)       (None, 784)               0
#
#  dense_786 (Dense)           (None, 82)                64370
#
#  dense_796 (Dense)           (None, 90)                7470
#
#  dense_806 (Dense)           (None, 39)                3549
#
#  dense_807 (Dense)           (None, 10)                400
#
# =================================================================
# Total params: 75,789
# Trainable params: 75,789
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# (0.8776000142097473,)
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_3 (Dense)             (None, 103)               80855
#
#  dense_15 (Dense)            (None, 118)               12272
#
#  dense_25 (Dense)            (None, 41)                4879
#
#  dense_26 (Dense)            (None, 10)                420
#
# =================================================================
# Total params: 98,426
# Trainable params: 98,426
# Non-trainable params: 0
# _________________________________________________________________
#
#
#
#
# (0.8944000005722046,)
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_163 (Flatten)       (None, 784)               0
#
#  dense_659 (Dense)           (None, 110)               86350
#
#  dense_660 (Dense)           (None, 75)                8325
#
#  dense_661 (Dense)           (None, 97)                7372
#
#  dense_662 (Dense)           (None, 10)                980
#
# =================================================================
# Total params: 103,027
# Trainable params: 103,027
# Non-trainable params: 0
# _________________________________________________________________
#
# (0.8799999952316284,)

# %% [markdown]
# KYLES FRAMEWORK:
#
# representation: trained neural net as individuals
#
# Mutation: 100%mutation probability,
#
# - add a dense layer, random nodes within range
#
#     copy parent
#
#     pop copy.output
#
#     add dense_layer
#
#     readd copy.output
#
#     train model
#
#     return accuracy
#
#
# - change activation function to another one
#
#     copy parent
#
#     pop copy.output
#
#     change activation of last layer
#
#     readd copy.output
#
#     train model
#
#     return accuracy
#
#
# - remove a layer (not valid for empty individual)
#
#     copy parent
#
#     pop copy.output
#
#     pop hidden layer
#
#     readd copy.output
#
#     train model
#
#     return accuracy
#
# -  add dropout (random percentage within a certain
#
# - mu + lambda selection strategy
